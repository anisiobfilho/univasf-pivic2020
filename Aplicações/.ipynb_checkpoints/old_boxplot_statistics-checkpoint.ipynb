# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon
import time
import timeit

# %%
start = timeit.default_timer()

# %%
def plot_boxplot(data, label_description):
    # Multiple box plots on one Axes
    fig, ax = plt.subplots(figsize=(16.00,9.00))
    ax.yaxis.grid(True, linestyle='-', which='major', color='lightgrey', alpha=0.5)
    ax.set(
        axisbelow=True,  # Hide the grid behind plot objects
        #title='Comparação entre Algoritmos',
        xlabel='Algorithm',
        ylabel='Acuracy',
        )
    # Set the axes ranges and axes labels
    #ax.set_xlim(0.5, len(data) + 0.5)
    #top = 40
    #bottom = -5
    #ax.set_ylim(bottom, top)
    #ax.set_xticklabels(np.repeat(label_description, 2), rotation=0, fontsize=8)
    ax.set_xticklabels(label_description, fontsize=8)
    ax.boxplot(data)
    return plt

# %%
#Dados:
tree = [0.6326530612244898,0.5816326530612245,0.6428571428571429,0.5918367346938775,0.5408163265306123,
        0.5876288659793815,0.6288659793814433,0.6185567010309279,0.5979381443298969,0.5463917525773195]
multinomialnb = [0.6836734693877551,0.7040816326530612,0.6632653061224489,0.6530612244897959,0.5714285714285714,
                 0.7319587628865979,0.7319587628865979,0.6391752577319587,0.6391752577319587,0.6391752577319587]
svc = [0.7346938775510204,0.7448979591836735,0.7040816326530612,0.7244897959183674,0.6122448979591837,
       0.7319587628865979,0.711340206185567,0.6597938144329897,0.6185567010309279,0.7010309278350515]
randomforest = [0.6938775510204082,0.7040816326530612,0.7040816326530612,0.6428571428571429,0.5510204081632653,
                0.7010309278350515,0.7010309278350515,0.6185567010309279,0.6185567010309279,0.6494845360824743]

# %%
label_description = ['Random Forest', 'Decision Tree']
data1 = [randomforest, tree]
plt = plot_boxplot(data1, label_description)
plt.show()
#plt.savefig('matplotlib/data-twitter/training/boxplot/randomforest-tree.png', format='png')
#plt.close()
# Out:
# C:\Users\anisi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
label_description = ['Random Forest', 'MNB']
data2 = [randomforest, multinomialnb]
plt = plot_boxplot(data2, label_description)
plt.show()
#plt.savefig('matplotlib/data-twitter/training/boxplot/randomforest-multinomialnb.png', format='png')
#plt.close()
# Out:
# C:\Users\anisi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
label_description = ['Random Forest', 'SVM']
data3 = [randomforest, svc]
plt = plot_boxplot(data3, label_description)
plt.show()
#plt.savefig('matplotlib/data-twitter/training/boxplot/randomforest-svc.png', format='png')
#plt.close()
# Out:
# C:\Users\anisi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
label_description = ['MNB', 'Decision Tree']
data4 = [multinomialnb, tree]
plt = plot_boxplot(data4, label_description)
plt.show()
#plt.savefig('matplotlib/data-twitter/training/boxplot/multinomialnb-tree.png', format='png')
#plt.close()
# Out:
# C:\Users\anisi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
label_description = ['MNB', 'Random Forest']
data5 = [multinomialnb, randomforest]
plt = plot_boxplot(data5, label_description)
plt.show()
#plt.savefig('matplotlib/data-twitter/training/boxplot/multinomialnb-randomforest.png', format='png')
#plt.close()
# Out:
# C:\Users\anisi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
label_description = ['MNB', 'SVM']
data6 = [multinomialnb, svc]
plt = plot_boxplot(data1, label_description)
plt.show()
#plt.savefig('matplotlib/data-twitter/training/boxplot/multinomialnb-svc.png', format='png')
#plt.close()
# Out:
# C:\Users\anisi\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
end = timeit.default_timer()
print ('Duração: %f segundos' % (end - start))
# Out:
# Duração: 1.660401 segundos
